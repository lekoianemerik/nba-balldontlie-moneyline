# %%
import pandas as pd
import requests
import time

# %%
SLEEP = 0
SEASONS = [2021, 2022, 2023]
with open('../balldontlie.apikey', 'r') as f:
    API_KEY = f.read()
    f.close()

# %% [markdown]
# # Helpers

# %%
def get_players_df(cursor):
    resp = requests.get(
        url='https://api.balldontlie.io/v1/players',
        params={
            'per_page': 100,
            'cursor': cursor
        },
        headers={
            'Authorization': API_KEY
        }
    )

    if resp.ok:
        print(f'on cursor {cursor}, meta: {resp.json()['meta']}')
        
        df = pd.Series(resp.json()['data']).apply(pd.Series)
        #df['current_team_id'] = df.team.apply(lambda x: x['id'])
        #df = df.drop(columns='team')

        if 'next_cursor' in resp.json()['meta'].keys():
            next_cursor = resp.json()['meta']['next_cursor']
        else:
            next_cursor = None

        return df, next_cursor
    
    else:
        print(f'FAIL cursor {cursor}')

        return None, None

# %%
def get_other_df(dfname, cursor):
    resp = requests.get(
        url=f'https://api.balldontlie.io/v1/{dfname}',
        params={
            'per_page': 100,
            'cursor': cursor,
            'seasons': SEASONS
        },
        headers={
            'Authorization': API_KEY
        }
    )

    if resp.ok:
        print(f'on cursor {cursor}, meta: {resp.json()['meta']}')
        
        df = pd.Series(resp.json()['data']).apply(pd.Series)
        #df['current_team_id'] = df.team.apply(lambda x: x['id'])
        #df = df.drop(columns='team')

        if 'next_cursor' in resp.json()['meta'].keys():
            next_cursor = resp.json()['meta']['next_cursor']
        else:
            next_cursor = None

        return df, next_cursor
    
    else:
        print(f'FAIL cursor {cursor}')

        return None, None

# %% [markdown]
# # Team Data

# %%
resp = requests.get(
    url='https://api.balldontlie.io/v1/teams',
    params={
        'per_page': 100,
        'cursor': 0
    },
    headers={
        'Authorization': API_KEY
    }
)

df = pd.Series(resp.json()['data']).apply(pd.Series)
df.to_csv('../data/data_raw/teams.csv', index=False)

# %% [markdown]
# # Player Data

# %%
dfs = []
cursor = 0

df, next_cursor = get_players_df(cursor)
dfs.append(df)

cursor = next_cursor

while cursor:

    df, next_cursor = get_players_df(cursor)
    dfs.append(df)

    cursor = next_cursor

    time.sleep(SLEEP)

df = pd.concat(dfs)
df.to_csv('../data/data_raw/players.csv', index=False)
# Out:
# on cursor 0, meta: {'next_cursor': 100, 'per_page': 100}
# on cursor 100, meta: {'prev_cursor': 100, 'next_cursor': 200, 'per_page': 100}
# on cursor 200, meta: {'prev_cursor': 200, 'next_cursor': 300, 'per_page': 100}
# on cursor 300, meta: {'prev_cursor': 300, 'next_cursor': 400, 'per_page': 100}
# on cursor 400, meta: {'prev_cursor': 400, 'next_cursor': 500, 'per_page': 100}
# on cursor 500, meta: {'prev_cursor': 500, 'next_cursor': 600, 'per_page': 100}
# on cursor 600, meta: {'prev_cursor': 600, 'next_cursor': 700, 'per_page': 100}
# on cursor 700, meta: {'prev_cursor': 700, 'next_cursor': 800, 'per_page': 100}
# on cursor 800, meta: {'prev_cursor': 800, 'next_cursor': 900, 'per_page': 100}
# on cursor 900, meta: {'prev_cursor': 900, 'next_cursor': 1000, 'per_page': 100}
# on cursor 1000, meta: {'prev_cursor': 1000, 'next_cursor': 1100, 'per_page': 100}
# on cursor 1100, meta: {'prev_cursor': 1100, 'next_cursor': 1200, 'per_page': 100}
# on cursor 1200, meta: {'prev_cursor': 1200, 'next_cursor': 1300, 'per_page': 100}
# on cursor 1300, meta: {'prev_cursor': 1300, 'next_cursor': 1400, 'per_page': 100}
# on cursor 1400, meta: {'prev_cursor': 1400, 'next_cursor': 1500, 'per_page': 100}
# on cursor 1500, meta: {'prev_cursor': 1500, 'next_cursor': 1600, 'per_page': 100}
# on cursor 1600, meta: {'prev_cursor': 1600, 'next_cursor': 1700, 'per_page': 100}
# on cursor 1700, meta: {'prev_cursor': 1700, 'next_cursor': 1800, 'per_page': 100}
# on cursor 1800, meta: {'prev_cursor': 1800, 'next_cursor': 1900, 'per_page': 100}
# on cursor 1900, meta: {'prev_cursor': 1900, 'next_cursor': 2000, 'per_page': 100}
# on cursor 2000, meta: {'prev_cursor': 2000, 'next_cursor': 2100, 'per_page': 100}
# on cursor 2100, meta: {'prev_cursor': 2100, 'next_cursor': 2200, 'per_page': 100}
# on cursor 2200, meta: {'prev_cursor': 2200, 'next_cursor': 2300, 'per_page': 100}
# on cursor 2300, meta: {'prev_cursor': 2300, 'next_cursor': 2400, 'per_page': 100}
# on cursor 2400, meta: {'prev_cursor': 2400, 'next_cursor': 2500, 'per_page': 100}
# on cursor 2500, meta: {'prev_cursor': 2500, 'next_cursor': 2600, 'per_page': 100}
# on cursor 2600, meta: {'prev_cursor': 2600, 'next_cursor': 2700, 'per_page': 100}
# on cursor 2700, meta: {'prev_cursor': 2700, 'next_cursor': 2800, 'per_page': 100}
# on cursor 2800, meta: {'prev_cursor': 2800, 'next_cursor': 2900, 'per_page': 100}
# on cursor 2900, meta: {'prev_cursor': 2900, 'next_cursor': 3000, 'per_page': 100}
# on cursor 3000, meta: {'prev_cursor': 3000, 'next_cursor': 50609, 'per_page': 100}
# on cursor 50609, meta: {'prev_cursor': 50609, 'next_cursor': 666758, 'per_page': 100}
# on cursor 666758, meta: {'prev_cursor': 666758, 'next_cursor': 3547261, 'per_page': 100}
# on cursor 3547261, meta: {'prev_cursor': 3547261, 'next_cursor': 4196900, 'per_page': 100}
# on cursor 4196900, meta: {'prev_cursor': 4196900, 'next_cursor': 17553999, 'per_page': 100}
# on cursor 17553999, meta: {'prev_cursor': 17553999, 'next_cursor': 17895911, 'per_page': 100}
# on cursor 17895911, meta: {'prev_cursor': 17895911, 'next_cursor': 17896098, 'per_page': 100}
# on cursor 17896098, meta: {'prev_cursor': 17896098, 'next_cursor': 38017711, 'per_page': 100}
# on cursor 38017711, meta: {'prev_cursor': 38017711, 'next_cursor': 46389629, 'per_page': 100}
# on cursor 46389629, meta: {'prev_cursor': 46389629, 'next_cursor': 46390223, 'per_page': 100}
# on cursor 46390223, meta: {'prev_cursor': 46390223, 'next_cursor': 46390817, 'per_page': 100}
# on cursor 46390817, meta: {'prev_cursor': 46390817, 'next_cursor': 46391411, 'per_page': 100}
# on cursor 46391411, meta: {'prev_cursor': 46391411, 'next_cursor': 46393487, 'per_page': 100}
# on cursor 46393487, meta: {'prev_cursor': 46393487, 'next_cursor': 46395069, 'per_page': 100}
# on cursor 46395069, meta: {'prev_cursor': 46395069, 'next_cursor': 46397639, 'per_page': 100}
# on cursor 46397639, meta: {'prev_cursor': 46397639, 'next_cursor': 46400209, 'per_page': 100}
# on cursor 46400209, meta: {'prev_cursor': 46400209, 'next_cursor': 46403273, 'per_page': 100}
# on cursor 46403273, meta: {'prev_cursor': 46403273, 'next_cursor': 46404361, 'per_page': 100}
# on cursor 46404361, meta: {'prev_cursor': 46404361, 'next_cursor': 46405449, 'per_page': 100}
# on cursor 46405449, meta: {'prev_cursor': 46405449, 'next_cursor': 46408513, 'per_page': 100}
# on cursor 46408513, meta: {'prev_cursor': 46408513, 'next_cursor': 46411084, 'per_page': 100}
# on cursor 46411084, meta: {'prev_cursor': 46411084, 'next_cursor': 56677872, 'per_page': 100}
# on cursor 56677872, meta: {'prev_cursor': 56677872, 'per_page': 100}

# %% [markdown]
# # Games Data

# %%
dfs = []
cursor = 0

df, next_cursor = get_other_df('games', cursor)
dfs.append(df)

cursor = next_cursor

while cursor:

    df, next_cursor = get_other_df('games', cursor)
    dfs.append(df)

    cursor = next_cursor

    time.sleep(SLEEP)

df = pd.concat(dfs)
df.to_csv('../data/data_raw/games.csv', index=False)
# Out:
# on cursor 0, meta: {'next_cursor': 473417, 'per_page': 100}
# on cursor 473417, meta: {'prev_cursor': 473417, 'next_cursor': 473515, 'per_page': 100}
# on cursor 473515, meta: {'prev_cursor': 473515, 'next_cursor': 473608, 'per_page': 100}
# on cursor 473608, meta: {'prev_cursor': 473608, 'next_cursor': 473709, 'per_page': 100}
# on cursor 473709, meta: {'prev_cursor': 473709, 'next_cursor': 473809, 'per_page': 100}
# on cursor 473809, meta: {'prev_cursor': 473809, 'next_cursor': 473909, 'per_page': 100}
# on cursor 473909, meta: {'prev_cursor': 473909, 'next_cursor': 474013, 'per_page': 100}
# on cursor 474013, meta: {'prev_cursor': 474013, 'next_cursor': 474106, 'per_page': 100}
# on cursor 474106, meta: {'prev_cursor': 474106, 'next_cursor': 474206, 'per_page': 100}
# on cursor 474206, meta: {'prev_cursor': 474206, 'next_cursor': 474312, 'per_page': 100}
# on cursor 474312, meta: {'prev_cursor': 474312, 'next_cursor': 474403, 'per_page': 100}
# on cursor 474403, meta: {'prev_cursor': 474403, 'next_cursor': 474505, 'per_page': 100}
# on cursor 474505, meta: {'prev_cursor': 474505, 'next_cursor': 474609, 'per_page': 100}
# on cursor 474609, meta: {'prev_cursor': 474609, 'next_cursor': 850125, 'per_page': 100}
# on cursor 850125, meta: {'prev_cursor': 850125, 'next_cursor': 857433, 'per_page': 100}
# on cursor 857433, meta: {'prev_cursor': 857433, 'next_cursor': 857535, 'per_page': 100}
# on cursor 857535, meta: {'prev_cursor': 857535, 'next_cursor': 857633, 'per_page': 100}
# on cursor 857633, meta: {'prev_cursor': 857633, 'next_cursor': 857740, 'per_page': 100}
# on cursor 857740, meta: {'prev_cursor': 857740, 'next_cursor': 857846, 'per_page': 100}
# on cursor 857846, meta: {'prev_cursor': 857846, 'next_cursor': 857938, 'per_page': 100}
# on cursor 857938, meta: {'prev_cursor': 857938, 'next_cursor': 858037, 'per_page': 100}
# on cursor 858037, meta: {'prev_cursor': 858037, 'next_cursor': 858140, 'per_page': 100}
# on cursor 858140, meta: {'prev_cursor': 858140, 'next_cursor': 858239, 'per_page': 100}
# on cursor 858239, meta: {'prev_cursor': 858239, 'next_cursor': 858338, 'per_page': 100}
# on cursor 858338, meta: {'prev_cursor': 858338, 'next_cursor': 858431, 'per_page': 100}
# on cursor 858431, meta: {'prev_cursor': 858431, 'next_cursor': 858542, 'per_page': 100}
# on cursor 858542, meta: {'prev_cursor': 858542, 'next_cursor': 892521, 'per_page': 100}
# on cursor 892521, meta: {'prev_cursor': 892521, 'next_cursor': 1037647, 'per_page': 100}
# on cursor 1037647, meta: {'prev_cursor': 1037647, 'next_cursor': 3277430, 'per_page': 100}
# on cursor 3277430, meta: {'prev_cursor': 3277430, 'next_cursor': 3277527, 'per_page': 100}
# on cursor 3277527, meta: {'prev_cursor': 3277527, 'next_cursor': 1037915, 'per_page': 100}
# on cursor 1037915, meta: {'prev_cursor': 1037915, 'next_cursor': 1038019, 'per_page': 100}
# on cursor 1038019, meta: {'prev_cursor': 1038019, 'next_cursor': 1038117, 'per_page': 100}
# on cursor 1038117, meta: {'prev_cursor': 1038117, 'next_cursor': 1038217, 'per_page': 100}
# on cursor 1038217, meta: {'prev_cursor': 1038217, 'next_cursor': 1038315, 'per_page': 100}
# on cursor 1038315, meta: {'prev_cursor': 1038315, 'next_cursor': 1038417, 'per_page': 100}
# on cursor 1038417, meta: {'prev_cursor': 1038417, 'next_cursor': 1038511, 'per_page': 100}
# on cursor 1038511, meta: {'prev_cursor': 1038511, 'next_cursor': 1038609, 'per_page': 100}
# on cursor 1038609, meta: {'prev_cursor': 1038609, 'next_cursor': 1038706, 'per_page': 100}
# on cursor 1038706, meta: {'prev_cursor': 1038706, 'next_cursor': 15883156, 'per_page': 100}
# on cursor 15883156, meta: {'prev_cursor': 15883156, 'per_page': 100}

# %%
gamesdf = pd.read_csv('../data/data_raw/games.csv')
gamesdf = gamesdf.sort_values('date')

# %% [markdown]
# # Stats Data

# %% [markdown]
# Doing it this way, because using cursors sometimes leads to "dead-ends" with stats data, aka not all games get loaded.

# %%
dfs = []
invalid_games = []

for i, row in gamesdf.iterrows():

    print(f'processing date={row.date}, game={row.id}')
    
    resp = requests.get(
        url='https://api.balldontlie.io/v1/stats',
        params={
            'game_ids[]': row.id
        },
        headers={
            'Authorization': API_KEY
        }
    )

    if resp.ok:
        df = pd.Series(resp.json()['data']).apply(pd.Series)
        dfs.append(df)
    else:
        invalid_games.append(row.id)

df = pd.concat(dfs)
df.to_csv('../data/data_raw/stats.csv', index=False)
# Out:
# processing date=2021-10-05, game=473368
# processing date=2021-10-05, game=473369
# processing date=2021-10-05, game=473366
# processing date=2021-10-19, game=473410
# processing date=2021-10-19, game=473409
# processing date=2021-10-20, game=473411
# processing date=2021-10-20, game=473412
# processing date=2021-10-20, game=473414
# processing date=2021-10-20, game=473415
# processing date=2021-10-20, game=473417
# processing date=2021-10-20, game=473413
# processing date=2021-10-20, game=473411
# processing date=2021-10-20, game=473420
# processing date=2021-10-20, game=473415
# processing date=2021-10-20, game=473412
# processing date=2021-10-20, game=473419
# processing date=2021-10-20, game=473414
# processing date=2021-10-20, game=473418
# processing date=2021-10-20, game=473416
# processing date=2021-10-20, game=473421
# processing date=2021-10-21, game=473423
# processing date=2021-10-21, game=473422
# processing date=2021-10-21, game=473424
# processing date=2021-10-22, game=473430
# processing date=2021-10-22, game=473432
# processing date=2021-10-22, game=473427
# processing date=2021-10-22, game=473428
# processing date=2021-10-22, game=473426
# processing date=2021-10-22, game=473425
# processing date=2021-10-22, game=473429
# processing date=2021-10-22, game=473434
# processing date=2021-10-22, game=473431
# processing date=2021-10-22, game=473433
# processing date=2021-10-23, game=473438
# processing date=2021-10-23, game=473436
# processing date=2021-10-23, game=473437
# processing date=2021-10-23, game=473442
# processing date=2021-10-23, game=473441
# processing date=2021-10-23, game=473440
# processing date=2021-10-23, game=473435
# processing date=2021-10-23, game=473439
# processing date=2021-10-24, game=473447
# processing date=2021-10-24, game=473443
# processing date=2021-10-24, game=473448
# processing date=2021-10-24, game=473444
# processing date=2021-10-24, game=473445
# processing date=2021-10-24, game=473446
# processing date=2021-10-25, game=473455
# processing date=2021-10-25, game=473450
# processing date=2021-10-25, game=473449
# processing date=2021-10-25, game=473456
# processing date=2021-10-25, game=473454
# processing date=2021-10-25, game=473452
# processing date=2021-10-25, game=473451
# processing date=2021-10-25, game=473453
# processing date=2021-10-25, game=473457
# processing date=2021-10-26, game=473462
# processing date=2021-10-26, game=473460
# processing date=2021-10-26, game=473459
# processing date=2021-10-26, game=473461
# processing date=2021-10-26, game=473458
# processing date=2021-10-27, game=473471
# processing date=2021-10-27, game=473469
# processing date=2021-10-27, game=473467
# processing date=2021-10-27, game=473472
# processing date=2021-10-27, game=473466
# processing date=2021-10-27, game=473463
# processing date=2021-10-27, game=473468
# processing date=2021-10-27, game=473465
# processing date=2021-10-27, game=473470
# processing date=2021-10-27, game=473464
# processing date=2021-10-28, game=473474
# processing date=2021-10-28, game=473475
# processing date=2021-10-28, game=473478
# processing date=2021-10-28, game=473473
# processing date=2021-10-28, game=473477
# processing date=2021-10-28, game=473476
# processing date=2021-10-29, game=473483
# processing date=2021-10-29, game=473481
# processing date=2021-10-29, game=473482
# processing date=2021-10-29, game=473484
# processing date=2021-10-29, game=473480
# processing date=2021-10-29, game=473485
# processing date=2021-10-29, game=473479
# processing date=2021-10-30, game=473494
# processing date=2021-10-30, game=473489
# processing date=2021-10-30, game=473492
# processing date=2021-10-30, game=473488
# processing date=2021-10-30, game=473496
# processing date=2021-10-30, game=473490
# processing date=2021-10-30, game=473495
# processing date=2021-10-30, game=473487
# processing date=2021-10-30, game=473486
# processing date=2021-10-30, game=473493
# processing date=2021-10-30, game=473491
# processing date=2021-10-31, game=473500
# processing date=2021-10-31, game=473498
# processing date=2021-10-31, game=473499
# processing date=2021-10-31, game=473497
# processing date=2021-10-31, game=473501
# processing date=2021-11-01, game=473507
# processing date=2021-11-01, game=473510
# processing date=2021-11-01, game=473504
# processing date=2021-11-01, game=473505
# processing date=2021-11-01, game=473502
# processing date=2021-11-01, game=473506
# processing date=2021-11-01, game=473509
# processing date=2021-11-01, game=473508
# processing date=2021-11-01, game=473503
# processing date=2021-11-02, game=473515
# processing date=2021-11-02, game=473513
# processing date=2021-11-02, game=473511
# processing date=2021-11-03, game=473523
# processing date=2021-11-03, game=473519
# processing date=2021-11-03, game=473522
# processing date=2021-11-03, game=473517
# processing date=2021-11-03, game=473520
# processing date=2021-11-03, game=473524
# processing date=2021-11-03, game=473521
# processing date=2021-11-03, game=473525
# processing date=2021-11-03, game=473516
# processing date=2021-11-03, game=473526
# processing date=2021-11-03, game=473518
# processing date=2021-11-04, game=473527
# processing date=2021-11-04, game=473530
# processing date=2021-11-04, game=473529
# processing date=2021-11-04, game=473528
# processing date=2021-11-04, game=473531
# processing date=2021-11-05, game=473538
# processing date=2021-11-05, game=473536
# processing date=2021-11-05, game=473534
# processing date=2021-11-05, game=473540
# processing date=2021-11-05, game=473533
# processing date=2021-11-05, game=473532
# processing date=2021-11-05, game=473535
# processing date=2021-11-05, game=473537
# processing date=2021-11-05, game=473539
# processing date=2021-11-06, game=473541
# processing date=2021-11-06, game=473542
# processing date=2021-11-06, game=473543
# processing date=2021-11-06, game=473544
# processing date=2021-11-06, game=473546
# processing date=2021-11-06, game=473545
# processing date=2021-11-07, game=473550
# processing date=2021-11-07, game=473547
# processing date=2021-11-07, game=473554
# processing date=2021-11-07, game=473553
# processing date=2021-11-07, game=473552
# processing date=2021-11-07, game=473548
# processing date=2021-11-07, game=473551
# processing date=2021-11-07, game=473549
# processing date=2021-11-08, game=473555
# processing date=2021-11-08, game=473557
# processing date=2021-11-08, game=473558
# processing date=2021-11-08, game=473556
# processing date=2021-11-08, game=473560
# processing date=2021-11-08, game=473559
# processing date=2021-11-08, game=473561
# processing date=2021-11-08, game=473562
# processing date=2021-11-09, game=473564
# processing date=2021-11-09, game=473563
# processing date=2021-11-09, game=473565
# processing date=2021-11-10, game=473569
# processing date=2021-11-10, game=473574
# processing date=2021-11-10, game=473572
# processing date=2021-11-10, game=473570
# processing date=2021-11-10, game=473571
# processing date=2021-11-10, game=473567
# processing date=2021-11-10, game=473573
# processing date=2021-11-10, game=473578
# processing date=2021-11-10, game=473566
# processing date=2021-11-10, game=473576
# processing date=2021-11-10, game=473575
# processing date=2021-11-10, game=473568
# processing date=2021-11-10, game=473577
# processing date=2021-11-11, game=473581
# processing date=2021-11-11, game=473579
# processing date=2021-11-11, game=473580
# processing date=2024-06-14, game=15905066
# processing date=2024-06-17, game=15905067

# %%
# processing INVALID games
dfs = []
invalid_games_twice = []

for gid in invalid_games:

    
    resp = requests.get(
        url='https://api.balldontlie.io/v1/stats',
        params={
            'game_ids[]': gid
        },
        headers={
            'Authorization': API_KEY
        }
    )

    if resp.ok:
        df = pd.Series(resp.json()['data']).apply(pd.Series)
        dfs.append(df)
        print(f'processing game={gid}, status OK')
    else:
        invalid_games_twice.append(gid)
        print(f'processing game={gid}, status INVALID')

df = pd.concat(dfs)
df.to_csv('../data/data_raw/stats_invalid.csv', index=False)
# Out:
# processing game=473978, status OK
# processing game=473984, status OK
# processing game=473980, status OK
# processing game=473986, status OK
# processing game=473988, status OK
# processing game=473989, status OK
# processing game=473987, status OK
# processing game=473991, status OK
# processing game=473992, status OK
# processing game=473993, status OK
# processing game=473995, status OK
# processing game=473990, status OK
# processing game=473998, status OK
# processing game=473996, status OK
# processing game=473994, status OK
# processing game=473997, status OK
# processing game=474002, status OK
# processing game=474003, status OK
# processing game=473999, status OK
# processing game=474001, status OK
# processing game=474004, status OK
# processing game=474000, status OK
# processing game=474010, status OK
# processing game=474014, status OK
# processing game=474011, status OK
# processing game=474009, status OK
# processing game=474006, status OK
# processing game=474008, status OK
# processing game=474007, status OK
# processing game=474013, status OK
# processing game=474016, status OK
# processing game=474015, status OK
# processing game=474017, status OK
# processing game=474018, status OK
# processing game=474019, status OK
# processing game=474020, status OK
# processing game=474022, status OK
# processing game=474021, status OK
# processing game=474024, status OK
# processing game=474023, status OK
# processing game=474025, status OK
# processing game=474034, status OK
# processing game=474030, status OK
# processing game=474027, status OK
# processing game=474028, status OK
# processing game=474031, status OK
# processing game=474026, status OK
# processing game=474033, status OK
# processing game=474032, status OK
# processing game=474029, status OK
# processing game=474039, status OK
# processing game=474035, status OK
# processing game=474038, status OK
# processing game=474036, status OK
# processing game=474037, status OK
# processing game=474047, status OK
# processing game=474041, status OK
# processing game=474044, status OK
# processing game=474043, status OK
# processing game=474046, status OK
# processing game=474042, status OK
# processing game=474040, status OK
# processing game=474045, status OK
# processing game=474048, status OK
# processing game=474054, status OK
# processing game=474056, status OK
# processing game=474050, status OK
# processing game=474058, status OK
# processing game=474055, status OK
# processing game=474057, status OK
# processing game=474052, status OK
# processing game=474049, status OK
# processing game=474053, status OK
# processing game=474051, status OK
# processing game=474061, status OK
# processing game=474060, status OK
# processing game=474059, status OK
# processing game=474072, status OK
# processing game=474068, status OK
# processing game=474073, status OK
# processing game=474064, status OK
# processing game=474065, status OK
# processing game=474066, status OK
# processing game=474062, status OK
# processing game=474063, status OK
# processing game=474071, status OK
# processing game=474070, status OK
# processing game=474069, status OK
# processing game=474067, status OK
# processing game=474075, status OK
# processing game=474074, status OK
# processing game=474077, status OK
# processing game=474082, status OK
# processing game=474080, status OK
# processing game=474079, status OK
# processing game=474086, status OK
# processing game=474076, status OK
# processing game=474085, status OK
# processing game=474088, status OK
# processing game=474083, status OK
# processing game=474087, status OK
# processing game=474078, status OK
# processing game=474081, status OK
# processing game=474084, status OK
# processing game=474090, status OK
# processing game=474089, status OK
# processing game=474091, status OK
# processing game=474092, status OK
# processing game=474101, status OK
# processing game=474097, status OK
# processing game=474098, status OK
# processing game=474095, status OK
# processing game=474096, status OK
# processing game=474100, status OK
# processing game=474099, status OK
# processing game=474094, status OK
# processing game=474093, status OK
# processing game=474102, status OK
# processing game=474105, status OK
# processing game=474104, status OK
# processing game=474103, status OK
# processing game=474116, status OK
# processing game=474112, status OK
# processing game=474115, status OK
# processing game=474107, status OK
# processing game=474110, status OK
# processing game=474113, status OK
# processing game=474108, status OK
# processing game=474114, status OK
# processing game=474109, status OK
# processing game=474110, status OK
# processing game=474108, status OK
# processing game=474106, status OK
# processing game=474111, status OK
# processing game=474109, status OK
# processing game=474116, status OK
# processing game=474107, status OK
# processing game=474115, status OK
# processing game=474113, status OK
# processing game=474117, status OK
# processing game=474119, status OK
# processing game=474118, status OK
# processing game=474121, status OK
# processing game=474120, status OK
# processing game=474129, status OK
# processing game=474125, status OK
# processing game=474124, status OK
# processing game=474126, status OK
# processing game=474123, status OK
# processing game=474127, status OK
# processing game=474122, status OK
# processing game=474128, status OK
# processing game=474140, status OK
# processing game=474133, status OK
# processing game=474139, status OK
# processing game=474136, status OK
# processing game=474135, status OK
# processing game=474131, status OK
# processing game=474132, status OK
# processing game=474130, status OK
# processing game=474134, status OK
# processing game=474138, status OK
# processing game=474137, status OK
# processing game=474142, status OK
# processing game=474141, status OK
# processing game=474143, status OK
# processing game=474149, status OK
# processing game=474151, status OK
# processing game=474150, status OK
# processing game=474146, status OK
# processing game=474147, status OK
# processing game=474152, status OK
# processing game=474145, status OK
# processing game=474144, status OK
# processing game=474148, status OK
# processing game=474157, status OK
# processing game=474154, status OK
# processing game=474158, status OK
# processing game=474156, status OK
# processing game=474155, status OK
# processing game=474153, status OK
# processing game=474160, status OK
# processing game=474162, status OK
# processing game=474165, status OK
# processing game=474163, status OK
# processing game=474166, status OK
# processing game=474164, status OK
# processing game=474161, status OK
# processing game=474159, status OK
# processing game=474172, status OK
# processing game=474171, status OK
# processing game=474167, status OK
# processing game=474168, status OK
# processing game=474169, status OK
# processing game=474173, status OK
# processing game=474170, status OK
# processing game=474174, status OK
# processing game=474179, status OK
# processing game=474176, status OK
# processing game=474180, status OK
# processing game=474175, status OK
# processing game=474178, status OK
# processing game=474177, status OK
# processing game=474181, status OK
# processing game=474182, status OK
# processing game=474187, status OK
# processing game=474186, status OK
# processing game=474189, status OK
# processing game=474183, status OK
# processing game=474184, status OK
# processing game=474185, status OK
# processing game=474188, status OK
# processing game=474191, status OK
# processing game=474190, status OK
# processing game=474192, status OK
# processing game=474193, status OK
# processing game=474194, status OK
# processing game=474196, status OK
# processing game=474195, status OK
# processing game=474198, status OK
# processing game=474202, status OK
# processing game=474203, status OK
# processing game=474197, status OK
# processing game=474199, status OK
# processing game=474200, status OK
# processing game=474201, status OK
# processing game=474205, status OK
# processing game=474209, status OK
# processing game=474207, status OK
# processing game=474206, status OK
# processing game=474207, status OK
# processing game=474208, status OK
# processing game=474214, status OK
# processing game=474217, status OK
# processing game=474210, status OK
# processing game=474215, status OK
# processing game=474216, status OK
# processing game=474213, status OK
# processing game=474212, status OK
# processing game=474211, status OK
# processing game=474221, status OK
# processing game=474222, status OK
# processing game=474218, status OK
# processing game=474220, status OK
# processing game=474219, status OK
# processing game=474228, status OK
# processing game=474224, status OK
# processing game=474225, status OK
# processing game=474231, status OK
# processing game=474232, status OK
# processing game=474223, status OK
# processing game=474227, status OK
# processing game=474226, status OK
# processing game=474230, status OK
# processing game=474229, status OK
# processing game=474236, status OK
# processing game=474238, status OK
# processing game=474233, status OK
# processing game=474235, status OK
# processing game=474237, status OK
# processing game=474234, status OK
# processing game=474241, status OK
# processing game=474244, status OK
# processing game=474240, status OK
# processing game=474242, status OK
# processing game=474243, status OK
# processing game=474245, status OK
# processing game=474239, status OK
# processing game=474252, status OK
# processing game=474251, status OK
# processing game=474263, status OK
# processing game=474262, status OK
# processing game=474260, status OK
# processing game=474261, status OK
# processing game=474256, status OK
# processing game=474257, status OK
# processing game=474259, status OK
# processing game=474254, status OK
# processing game=474265, status OK
# processing game=474264, status OK
# processing game=474274, status OK
# processing game=474267, status OK
# processing game=474273, status OK
# processing game=474268, status OK
# processing game=474270, status OK
# processing game=474271, status OK
# processing game=474266, status OK
# processing game=474269, status OK
# processing game=474272, status OK
# processing game=474276, status OK
# processing game=474279, status OK
# processing game=474281, status OK
# processing game=474278, status OK
# processing game=474280, status OK
# processing game=474275, status OK
# processing game=474277, status OK
# processing game=474282, status OK
# processing game=474285, status OK
# processing game=474287, status OK
# processing game=474292, status OK
# processing game=474284, status OK
# processing game=474290, status OK
# processing game=474289, status OK
# processing game=474288, status OK
# processing game=474286, status OK
# processing game=474283, status OK
# processing game=474291, status OK
# processing game=474293, status OK
# processing game=474295, status OK
# processing game=474296, status OK
# processing game=474294, status OK
# processing game=474302, status OK
# processing game=474303, status OK
# processing game=474300, status OK
# processing game=474301, status OK
# processing game=474297, status OK
# processing game=474298, status OK
# processing game=474299, status OK
# processing game=474307, status OK
# processing game=474310, status OK
# processing game=474312, status OK
# processing game=474309, status OK
# processing game=474304, status OK
# processing game=474313, status OK
# processing game=474319, status OK
# processing game=474316, status OK
# processing game=474317, status OK
# processing game=474318, status OK
# processing game=474315, status OK
# processing game=474314, status OK
# processing game=474327, status OK
# processing game=474321, status OK
# processing game=474320, status OK
# processing game=474326, status OK
# processing game=474324, status OK
# processing game=474323, status OK
# processing game=474325, status OK
# processing game=474322, status OK
# processing game=474333, status OK
# processing game=474331, status OK
# processing game=474329, status OK
# processing game=474328, status OK
# processing game=474332, status OK
# processing game=474330, status OK
# processing game=474335, status OK
# processing game=474339, status OK
# processing game=474338, status OK
# processing game=474336, status OK
# processing game=474334, status OK
# processing game=474337, status OK
# processing game=474342, status OK
# processing game=474346, status OK
# processing game=474340, status OK
# processing game=474343, status OK
# processing game=474345, status OK
# processing game=474344, status OK
# processing game=474341, status OK
# processing game=474347, status OK
# processing game=474350, status OK
# processing game=474351, status OK
# processing game=474349, status OK
# processing game=474352, status OK
# processing game=474353, status OK
# processing game=474348, status OK
# processing game=474361, status OK
# processing game=474360, status OK
# processing game=474359, status OK
# processing game=474355, status OK
# processing game=474357, status OK
# processing game=474358, status OK
# processing game=474354, status OK
# processing game=474356, status OK
# processing game=474367, status OK
# processing game=474366, status OK
# processing game=474362, status OK
# processing game=474365, status OK
# processing game=474363, status OK
# processing game=474364, status OK
# processing game=474372, status OK
# processing game=474375, status OK
# processing game=474370, status OK
# processing game=474369, status OK
# processing game=474505, status OK
# processing game=474506, status OK
# processing game=474511, status OK
# processing game=474510, status OK
# processing game=474508, status OK
# processing game=474509, status OK
# processing game=474512, status OK
# processing game=474514, status OK
# processing game=474513, status OK
# processing game=474518, status OK
# processing game=474522, status OK
# processing game=474519, status OK
# processing game=474515, status OK
# processing game=474520, status OK
# processing game=474516, status OK
# processing game=474517, status OK
# processing game=474521, status OK
# processing game=474523, status OK
# processing game=474525, status OK
# processing game=474526, status OK
# processing game=474529, status OK
# processing game=474524, status OK
# processing game=474528, status OK
# processing game=474527, status OK
# processing game=474533, status OK
# processing game=474535, status OK
# processing game=474534, status OK
# processing game=474532, status OK
# processing game=474537, status OK
# processing game=474531, status OK
# processing game=474538, status OK
# processing game=474536, status OK
# processing game=474530, status OK
# processing game=474542, status OK
# processing game=474543, status OK
# processing game=474540, status OK
# processing game=474541, status OK
# processing game=474539, status OK
# processing game=474554, status OK
# processing game=474549, status OK
# processing game=474552, status OK
# processing game=474544, status OK
# processing game=474546, status OK
# processing game=474553, status OK
# processing game=474548, status OK
# processing game=474547, status OK
# processing game=474550, status OK
# processing game=474545, status OK
# processing game=474551, status OK
# processing game=474555, status OK
# processing game=474558, status OK
# processing game=474556, status OK
# processing game=474557, status OK
# processing game=474568, status OK
# processing game=474563, status OK
# processing game=474562, status OK
# processing game=474559, status OK
# processing game=474565, status OK
# processing game=474566, status OK
# processing game=474564, status OK
# processing game=474561, status OK
# processing game=474560, status OK
# processing game=474567, status OK
# processing game=474569, status OK
# processing game=474571, status OK
# processing game=474572, status OK
# processing game=474573, status OK
# processing game=474570, status OK
# processing game=474581, status OK
# processing game=474578, status OK
# processing game=474576, status OK
# processing game=474583, status OK
# processing game=474582, status OK
# processing game=474577, status OK
# processing game=474585, status OK
# processing game=474579, status OK
# processing game=474575, status OK
# processing game=474580, status OK
# processing game=474574, status OK
# processing game=474584, status OK
# processing game=474589, status OK
# processing game=474588, status OK
# processing game=474593, status OK
# processing game=474586, status OK
# processing game=474590, status OK
# processing game=474591, status OK
# processing game=474587, status OK
# processing game=474597, status OK
# processing game=474595, status OK
# processing game=474592, status OK
# processing game=474594, status OK
# processing game=474596, status OK
# processing game=474600, status OK
# processing game=474603, status OK
# processing game=474598, status OK
# processing game=474599, status OK
# processing game=474601, status OK
# processing game=474602, status OK
# processing game=474610, status OK
# processing game=474604, status OK
# processing game=474609, status OK
# processing game=474607, status OK
# processing game=474608, status OK
# processing game=474619, status OK
# processing game=474617, status OK
# processing game=474611, status OK
# processing game=474616, status OK
# processing game=474614, status OK
# processing game=474615, status OK
# processing game=474613, status OK
# processing game=474612, status OK
# processing game=474618, status OK
# processing game=474622, status OK
# processing game=474621, status OK
# processing game=474620, status OK
# processing game=474623, status OK
# processing game=474633, status OK
# processing game=474626, status OK
# processing game=474629, status OK
# processing game=474631, status OK
# processing game=474637, status OK
# processing game=474630, status OK
# processing game=474632, status OK
# processing game=474638, status OK
# processing game=474636, status OK
# processing game=474634, status OK
# processing game=474627, status OK
# processing game=474635, status OK
# processing game=474624, status OK
# processing game=474628, status OK
# processing game=474625, status OK
# processing game=830510, status OK
# processing game=830509, status OK
# processing game=830799, status OK
# processing game=830800, status OK
# processing game=831662, status OK
# processing game=831661, status OK
# processing game=831951, status OK
# processing game=831952, status OK
# processing game=831953, status OK
# processing game=831954, status OK
# processing game=832817, status OK
# processing game=832819, status OK
# processing game=832818, status OK
# processing game=832820, status OK
# processing game=833969, status OK
# processing game=833971, status OK
# processing game=833970, status OK
# processing game=834977, status OK
# processing game=834976, status OK
# processing game=834978, status OK
# processing game=835840, status OK
# processing game=835842, status OK
# processing game=835841, status OK
# processing game=836706, status OK
# processing game=836704, status OK
# processing game=836705, status OK
# processing game=837570, status OK
# processing game=837569, status OK
# processing game=837568, status OK
# processing game=838434, status OK
# processing game=838433, status OK
# processing game=838432, status OK
# processing game=838435, status OK
# processing game=839443, status OK
# processing game=839444, status OK
# processing game=839441, status OK
# processing game=839442, status OK
# processing game=840594, status OK
# processing game=840595, status OK
# processing game=840593, status OK
# processing game=841601, status OK
# processing game=841602, status OK
# processing game=841600, status OK
# processing game=842464, status OK
# processing game=842465, status OK
# processing game=843183, status OK
# processing game=843184, status OK
# processing game=843185, status OK
# processing game=843904, status OK
# processing game=844653, status OK
# processing game=844654, status OK
# processing game=844943, status OK
# processing game=844944, status OK
# processing game=845519, status OK
# processing game=845520, status OK
# processing game=846096, status OK
# processing game=846095, status OK
# processing game=846956, status OK
# processing game=847245, status OK

# %% [markdown]
# # Advanced Stats Data

# %%
dfs = []
invalid_games = []

for i, row in gamesdf.iterrows():
    
    resp = requests.get(
        url='https://api.balldontlie.io/v1/stats/advanced',
        params={
            'game_ids[]': row.id
        },
        headers={
            'Authorization': API_KEY
        }
    )

    if resp.ok:
        df = pd.Series(resp.json()['data']).apply(pd.Series)
        dfs.append(df)
        print(f'processing date={row.date}, game={row.id}, status=OK')
    else:
        invalid_games.append(row.id)
        print(f'processing date={row.date}, game={row.id}, status=INVALID')

df = pd.concat(dfs)
df.to_csv('../data/data_raw/advanced.csv', index=False)

# %%
df['date'] = df.game.apply(lambda x: x['date'])

# %%
df.date.max()
# Out:
# '2022-03-11'

# %%
get_other_df('games', 10851598)
# Out:
# on cursor 10851598, meta: {'prev_cursor': 10851598, 'per_page': 100}
# (Series([], dtype: object), None)
